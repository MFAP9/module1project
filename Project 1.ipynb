# %%
#Imported panda, numpy, matplotlib.pyplot, and seaborn libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline
sns.set()

# %% [markdown]
# Now, we will be reviewing all of the available data sets and sorting out which ones to use for analysis and which ones to discard.

# %%
bom = pd.read_csv('datauz/bom.movie_gross.csv')
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom.info()
bom.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
imdbname = pd.read_csv('datauz/imdb.name.basics.csv')
imdbname.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
imdbname.info()
imdbname.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB
#          birth_year   death_year
# count  82736.000000  6783.000000
# mean    1967.043826  2000.523367
# std       22.122190    43.951530
# min        1.000000    17.000000
# 25%     1957.000000  2001.000000
# 50%     1971.000000  2013.000000
# 75%     1981.000000  2016.000000
# max     2014.000000  2019.000000

# %%
#Exploring all the data from IMDB
imdbbasics = pd.read_csv('datauz/imdb.title.basics.csv')
imdbbasics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdbbasics.info()
imdbbasics.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
imdbprincipals = pd.read_csv('datauz/imdb.title.principals.csv')
imdbprincipals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
imdbprincipals.info()
imdbprincipals.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
#            ordering
# count  1.028186e+06
# mean   4.739847e+00
# std    2.747446e+00
# min    1.000000e+00
# 25%    2.000000e+00
# 50%    4.000000e+00
# 75%    7.000000e+00
# max    1.000000e+01

# %%
imdbcrew = pd.read_csv('datauz/imdb.title.crew.csv')
imdbcrew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
imdbcrew.info()
imdbcrew.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB
#            tconst  directors    writers
# count      146144     140417     110261
# unique     146144      98525      91920
# top     tt1625196  nm3266654  nm0000636
# freq            1         62         80

# %%
imdbratings = pd.read_csv('datauz/imdb.title.ratings.csv')
imdbratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
imdbratings.info()
imdbratings.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
imdbakas = pd.read_csv('datauz/imdb.title.akas.csv')
imdbakas.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
imdbakas.info()
imdbakas.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ordering             331703 non-null int64
# title                331703 non-null object
# region               278410 non-null object
# language             41715 non-null object
# types                168447 non-null object
# attributes           14925 non-null object
# is_original_title    331678 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB
#             ordering  is_original_title
# count  331703.000000      331678.000000
# mean        5.125872           0.134769
# std         6.706664           0.341477
# min         1.000000           0.000000
# 25%         1.000000           0.000000
# 50%         2.000000           0.000000
# 75%         6.000000           0.000000
# max        61.000000           1.000000

# %%
tmdb = pd.read_csv('datauz/tmdb.movies.csv')
tmdb.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb.info()
tmdb.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
# Unnamed: 0           26517 non-null int64
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
#Import tn dataset originally (https://www.the-numbers.com/movie/budgets/all)
tn = pd.read_csv('datauz/tn.movie_budgets.csv')
tn.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn.info()
tn.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB
#                 id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %%
#converting production_budget, domestic_gross, and worldwide_gross from objects to int values
#converting release_date from obejct to datetime value
tn.production_budget = tn.production_budget.replace('[\$,]', '', regex=True).astype(int)
tn.domestic_gross = tn.domestic_gross.replace('[\$,]', '', regex=True).astype(int)
tn.worldwide_gross = tn.worldwide_gross.replace('[\$,]', '', regex=True).astype(int)
tn.release_date = pd.to_datetime(tn.release_date)

# %%
tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null datetime64[ns]
# movie                5782 non-null object
# production_budget    5782 non-null int64
# domestic_gross       5782 non-null int64
# worldwide_gross      5782 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.1+ KB

# %%
tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
#created international_gross variable to assist in seeing success internationally compared to domestically
tn['international_gross'] = tn.worldwide_gross - tn.domestic_gross
tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  international_gross
# 0          425000000       760507625       2776345279           2015837654
# 1          410600000       241063875       1045663875            804600000
# 2          350000000        42762350        149762350            107000000
# 3          330600000       459005868       1403013963            944008095
# 4          317000000       620181382       1316721747            696540365

# %%
#created profit variable to show overall success of movie, which is determined by how much profit it made
tn['profit'] = tn.worldwide_gross - tn.production_budget
tn.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  international_gross  \
# 0          425000000       760507625       2776345279           2015837654
# 1          410600000       241063875       1045663875            804600000
# 2          350000000        42762350        149762350            107000000
# 3          330600000       459005868       1403013963            944008095
# 4          317000000       620181382       1316721747            696540365
#
#        profit
# 0  2351345279
# 1   635063875
# 2  -200237650
# 3  1072413963
# 4   999721747

# %%
#creating subset of tn dataset to use movies only from 2010-2018
tn_2010_2018 = tn[(tn.release_date >= '2010-01-01') & (tn.release_date <= '2018-12-31')]
tn_2010_2018.release_date.describe()
# Out:
# count                    2124
# unique                    692
# top       2014-12-31 00:00:00
# freq                       24
# first     2010-01-08 00:00:00
# last      2018-12-31 00:00:00
# Name: release_date, dtype: object

# %%
tn_2010_2018.head()
# Out:
#    id release_date                                        movie  \
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   6   2015-12-18         Star Wars Ep. VII: The Force Awakens
# 6   7   2018-04-27                       Avengers: Infinity War
#
#    production_budget  domestic_gross  worldwide_gross  international_gross  \
# 1          410600000       241063875       1045663875            804600000
# 3          330600000       459005868       1403013963            944008095
# 4          317000000       620181382       1316721747            696540365
# 5          306000000       936662225       2053311220           1116648995
# 6          300000000       678815482       2048134200           1369318718
#
#        profit
# 1   635063875
# 3  1072413963
# 4   999721747
# 5  1747311220
# 6  1748134200

# %%
#sorting tn data set by profit, descending
tn_2010_2018 = tn_2010_2018.sort_values(by='profit', ascending=False)
tn_2010_2018.head()
# Out:
#     id release_date                                 movie  production_budget  \
# 6    7   2018-04-27                Avengers: Infinity War          300000000
# 5    6   2015-12-18  Star Wars Ep. VII: The Force Awakens          306000000
# 33  34   2015-06-12                        Jurassic World          215000000
# 66  67   2015-04-03                             Furious 7          190000000
# 26  27   2012-05-04                          The Avengers          225000000
#
#     domestic_gross  worldwide_gross  international_gross      profit
# 6        678815482       2048134200           1369318718  1748134200
# 5        936662225       2053311220           1116648995  1747311220
# 33       652270625       1648854864            996584239  1433854864
# 66       353007020       1518722794           1165715774  1328722794
# 26       623279547       1517935897            894656350  1292935897

# %%
#created data set of top 100 most profitable movies from TN data set
tn100 = tn_2010_2018.head(100)
tn100
# Out:
#       id release_date                                          movie  \
# 6      7   2018-04-27                         Avengers: Infinity War
# 5      6   2015-12-18           Star Wars Ep. VII: The Force Awakens
# 33    34   2015-06-12                                 Jurassic World
# 66    67   2015-04-03                                      Furious 7
# 26    27   2012-05-04                                   The Avengers
# 260   61   2011-07-15  Harry Potter and the Deathly Hallows: Part II
# 41    42   2018-02-16                                  Black Panther
# 112   13   2018-06-22                 Jurassic World: Fallen Kingdom
# 155   56   2013-11-22                                         Frozen
# 134   35   2017-03-17                           Beauty and the Beast
# 672   73   2015-07-10                                        Minions
# 3      4   2015-05-01                        Avengers: Age of Ultron
# 43    44   2018-06-15                                  Incredibles 2
# 47    48   2013-05-03                                     Iron Man 3
# 4      5   2017-12-15              Star Wars Ep. VIII: The Last Jedi
# 135   36   2018-12-21                                        Aquaman
# 22    23   2017-04-14                        The Fate of the Furious
# 629   30   2017-06-30                                Despicable Me 3
# 63    64   2011-06-29                 Transformers: Dark of the Moon
# 51    52   2012-11-08                                        Skyfall
# 621   22   2013-07-03                                Despicable Me 2
# 36    37   2014-06-27                Transformers: Age of Extinction
# 16    17   2016-05-06                     Captain America: Civil War
# 437   38   2017-12-20                 Jumanji: Welcome to the Jungle
# 156   57   2016-03-04                                       Zootopia
# 46    47   2010-06-18                                    Toy Story 3
# 44    45   2016-12-16                   Rogue One: A Star Wars Story
# 983   84   2018-11-02                              Bohemian Rhapsody
# 263   64   2010-11-19   Harry Potter and the Deathly Hallows: Part I
# 167           150000000       195042377        688858992            493816615
# 30            220000000       262030663        757890267            495859604
# 1377           40000000       166167230        570998101            404830871
# 173           150000000       165249063        664837547            499588484
# 127           165000000       232641920        676404566            443762646
# 55            200000000       202853933        708996336            506142403
# 538            80000000       254464305        586464305            332000000
# 1083           50000000       218665740        556016627            337350887
# 266           125000000       210031325        630163454            420132129
# 131           165000000       188017894        666379375            478361481
# 287           120000000       124987022        620912003            495924981
# 165           150000000       206362140        644602516            438240376
# 841            60720000         3229457        554516671            551287214
# 240           130000000       216648740        623144660            406495920
# 956            58000000       350126372        547326372            197200000
# 138           160000000       281723902        648986787            367262885
# 258           127000000       226277068        615461394            389184326
# 161           150000000       248757044        637517365            388760321
# 128           165000000       222527828        652127828            429600000
# 749            69000000       251513985        543464573            291950588
# 3517           10800000        13182281        484873045            471690764
# 198           145000000       177002924        614586270            437583346
# 776            65000000       167500092        527079962            359579870
# 319           110000000       142614158        563749323            421135165
# 59            200000000       159555901        652220086            492664185
#
#           profit
# 6     1748134200
# 5     1747311220
# 33    1433854864
# 66    1328722794
# 26    1292935897
# 260   1216693157
# 41    1148258224
# 112   1135772799
# 155   1122469910
# 134   1099199706
# 672   1086336173
# 3     1072413963
# 43    1042520711
# 47    1015392272
# 4      999721747
# 135    986894640
# 22     984846267
# 629    959727750
# 63     928790543
# 51     910526981
# 621    899216835
# 36     894039076
# 16     890069413
# 437    874496193
# 156    869429616
# 46     868879522
# 44     849102856
# 983    839985342
# 263    835431568
# 50     825491110
# ...          ...
# 54     547862775
# 345    547271443
# 115    544401889
# 52     543588329
# 116    540644566
# 167    538858992
# 30     537890267
# 1377   530998101
# 173    514837547
# 127    511404566
# 55     508996336
# 538    506464305
# 1083   506016627
# 266    505163454
# 131    501379375
# 287    500912003
# 165    494602516
# 841    493796671
# 240    493144660
# 956    489326372
# 138    488986787
# 258    488461394
# 161    487517365
# 128    487127828
# 749    474464573
# 3517   474073045
# 198    469586270
# 776    462079962
# 319    453749323
# 59     452220086
#
# [100 rows x 8 columns]

# %%
tn100.info()
tn100.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 6 to 59
# Data columns (total 8 columns):
# id                     100 non-null int64
# release_date           100 non-null datetime64[ns]
# movie                  100 non-null object
# production_budget      100 non-null int64
# domestic_gross         100 non-null int64
# worldwide_gross        100 non-null int64
# international_gross    100 non-null int64
# profit                 100 non-null int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 7.0+ KB
#                id  production_budget  domestic_gross  worldwide_gross  \
# count  100.000000       1.000000e+02    1.000000e+02     1.000000e+02
# mean    45.270000       1.615642e+08    3.118346e+08     8.960604e+08
# std     26.738485       7.088174e+07    1.425826e+08     3.000080e+08
# min      2.000000       1.080000e+07    3.229457e+06     4.848730e+08
# 25%     23.750000       1.190000e+08    2.197858e+08     6.861251e+08
# 50%     42.000000       1.625000e+08    2.815055e+08     8.117681e+08
# 75%     62.000000       2.000000e+08    3.650172e+08     1.037462e+09
# max    100.000000       4.106000e+08    9.366622e+08     2.053311e+09
#
#        international_gross        profit
# count         1.000000e+02  1.000000e+02
# mean          5.842258e+08  7.344962e+08
# std           2.035347e+08  2.666163e+08
# min           1.972000e+08  4.522201e+08
# 25%           4.378900e+08  5.401982e+08
# 50%           5.312258e+08  6.519457e+08
# 75%           6.906684e+08  8.690170e+08
# max           1.369319e+09  1.748134e+09

# %%
#average budget of 100 most profitable movies
np.mean(tn100['production_budget'])
# Out:
# 161564200.0

# %%
#data set of 100 least profitable movies
tnbottom100 = tn.tail(100)

# %%
#average budget of 100 least profitable movies
np.mean(tnbottom100['production_budget'])
# Out:
# 45188.0

# %%
#merged principals and name data sets based on nconst column
imdbmerge = pd.merge(imdbprincipals, imdbname, on = 'nconst')
imdbmerge.head()
# Out:
#       tconst  ordering     nconst  category       job   characters  \
# 0  tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN          NaN
# 2  tt5573596         5  nm0398271  director       NaN          NaN
# 3  tt0111414         3  nm3739909  producer  producer          NaN
# 4  tt0323808        10  nm0059247    editor       NaN          NaN
#
#             primary_name  birth_year  death_year  \
# 0           Tommy Dysart         NaN         NaN
# 1           Frank Howson      1952.0         NaN
# 2           Frank Howson      1952.0         NaN
# 3  Barry Porter-Robinson         NaN         NaN
# 4            Sean Barton      1944.0         NaN
#
#                                primary_profession  \
# 0                                           actor
# 1                           actor,writer,producer
# 2                           actor,writer,producer
# 3                         producer,art_department
# 4  editor,editorial_department,assistant_director
#
#                           known_for_titles
# 0  tt0093120,tt0076974,tt0084296,tt0077064
# 1  tt0104271,tt0094789,tt0102076,tt0111414
# 2  tt0104271,tt0094789,tt0102076,tt0111414
# 3  tt0290884,tt0101374,tt0111414,tt1566940
# 4  tt0402910,tt1022883,tt0086190,tt0490181

# %%
#then merged data set with basics data set based on tconst column
imdbfinal = pd.merge(imdbmerge, imdbbasics, on = 'tconst')
imdbfinal.head()
# Out:
#       tconst  ordering     nconst  category       job   characters  \
# 0  tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN          NaN
# 2  tt0111414         3  nm3739909  producer  producer          NaN
# 3  tt5573596         5  nm0398271  director       NaN          NaN
# 4  tt5573596         4  nm0000476   actress       NaN          NaN
#
#             primary_name  birth_year  death_year  \
# 0           Tommy Dysart         NaN         NaN
# 1           Frank Howson      1952.0         NaN
# 2  Barry Porter-Robinson         NaN         NaN
# 3           Frank Howson      1952.0         NaN
# 4         Sally Kirkland      1941.0         NaN
#
#                primary_profession                         known_for_titles  \
# 0                           actor  tt0093120,tt0076974,tt0084296,tt0077064
# 1           actor,writer,producer  tt0104271,tt0094789,tt0102076,tt0111414
# 2         producer,art_department  tt0290884,tt0101374,tt0111414,tt1566940
# 3           actor,writer,producer  tt0104271,tt0094789,tt0102076,tt0111414
# 4  actress,producer,miscellaneous  tt0315327,tt0092569,tt3216866,tt0102138
#
#        primary_title     original_title  start_year  runtime_minutes  genres
# 0        A Thin Life        A Thin Life        2018             75.0  Comedy
# 1        A Thin Life        A Thin Life        2018             75.0  Comedy
# 2        A Thin Life        A Thin Life        2018             75.0  Comedy
# 3  Remembering Nigel  Remembering Nigel        2015              NaN  Comedy
# 4  Remembering Nigel  Remembering Nigel        2015              NaN  Comedy

# %%
#changed column name to movie to prepare for merge with TN data set
imdbfinal = imdbfinal.rename(columns = {'primary_title': 'movie'})
imdbfinal.head()
# Out:
#       tconst  ordering     nconst  category       job   characters  \
# 0  tt0111414         1  nm0246005     actor       NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN          NaN
# 2  tt0111414         3  nm3739909  producer  producer          NaN
# 3  tt5573596         5  nm0398271  director       NaN          NaN
# 4  tt5573596         4  nm0000476   actress       NaN          NaN
#
#             primary_name  birth_year  death_year  \
# 0           Tommy Dysart         NaN         NaN
# 1           Frank Howson      1952.0         NaN
# 2  Barry Porter-Robinson         NaN         NaN
# 3           Frank Howson      1952.0         NaN
# 4         Sally Kirkland      1941.0         NaN
#
#                primary_profession                         known_for_titles  \
# 0                           actor  tt0093120,tt0076974,tt0084296,tt0077064
# 1           actor,writer,producer  tt0104271,tt0094789,tt0102076,tt0111414
# 2         producer,art_department  tt0290884,tt0101374,tt0111414,tt1566940
# 3           actor,writer,producer  tt0104271,tt0094789,tt0102076,tt0111414
# 4  actress,producer,miscellaneous  tt0315327,tt0092569,tt3216866,tt0102138
#
#                movie     original_title  start_year  runtime_minutes  genres
# 0        A Thin Life        A Thin Life        2018             75.0  Comedy
# 1        A Thin Life        A Thin Life        2018             75.0  Comedy
# 2        A Thin Life        A Thin Life        2018             75.0  Comedy
# 3  Remembering Nigel  Remembering Nigel        2015              NaN  Comedy
# 4  Remembering Nigel  Remembering Nigel        2015              NaN  Comedy

# %%
#Merging TN dataframe with IMDB merged dataframe based on movie column
tnfinal = pd.merge(imdbfinal, tn100, on = 'movie', how = 'right')
tnfinal.head()
# Out:
#       tconst  ordering     nconst  category         job  \
# 0  tt5463162       2.0  nm0000982     actor         NaN
# 1  tt5463162       6.0  nm1014201    writer  written by
# 2  tt5463162       7.0  nm1116660    writer  written by
# 3  tt5463162       1.0  nm0005351     actor         NaN
# 4  tt5463162      10.0  nm1334526  producer    producer
#
#                                          characters   primary_name  \
# 0                                         ["Cable"]    Josh Brolin
# 1                                               NaN    Rhett Reese
# 2                                               NaN   Paul Wernick
# 3  ["Wade Wilson","Deadpool","Voice of Juggernaut"]  Ryan Reynolds
# 4                                               NaN  Simon Kinberg
#
#    birth_year  death_year             primary_profession  ... start_year  \
# 0      1968.0         NaN          actor,producer,writer  ...     2018.0
# 1         NaN         NaN  writer,producer,miscellaneous  ...     2018.0
# 2         NaN         NaN       producer,writer,director  ...     2018.0
# 3      1976.0         NaN      actor,producer,soundtrack  ...     2018.0
# 4      1973.0         NaN       producer,writer,director  ...     2018.0
#
#   runtime_minutes                   genres  id  release_date  \
# 0           119.0  Action,Adventure,Comedy  15    2018-05-18
# 1           119.0  Action,Adventure,Comedy  15    2018-05-18
# 2           119.0  Action,Adventure,Comedy  15    2018-05-18
# 3           119.0  Action,Adventure,Comedy  15    2018-05-18
# 4           119.0  Action,Adventure,Comedy  15    2018-05-18
#
#   production_budget  domestic_gross worldwide_gross  international_gross  \
# 0         110000000       324591735       786680557            462088822
# 1         110000000       324591735       786680557            462088822
# 2         110000000       324591735       786680557            462088822
# 3         110000000       324591735       786680557            462088822
# 4         110000000       324591735       786680557            462088822
#
#       profit
# 0  676680557
# 1  676680557
# 2  676680557
# 3  676680557
# 4  676680557
#
# [5 rows x 23 columns]

# %%
#removed any unneeded columns from the data set
tnfinal = tnfinal.drop(columns=['job', 'characters', 'birth_year', 'death_year', 'primary_profession', 'original_title'])
tnfinal.head()
# Out:
#       tconst  ordering     nconst  category   primary_name  \
# 0  tt5463162       2.0  nm0000982     actor    Josh Brolin
# 1  tt5463162       6.0  nm1014201    writer    Rhett Reese
# 2  tt5463162       7.0  nm1116660    writer   Paul Wernick
# 3  tt5463162       1.0  nm0005351     actor  Ryan Reynolds
# 4  tt5463162      10.0  nm1334526  producer  Simon Kinberg
#
#                           known_for_titles       movie  start_year  \
# 0  tt4154756,tt1175491,tt0477348,tt1791528  Deadpool 2      2018.0
# 1  tt5442430,tt1156398,tt1583421,tt1431045  Deadpool 2      2018.0
# 2  tt1431045,tt5442430,tt1156398,tt1583421  Deadpool 2      2018.0
# 3  tt5463162,tt1462758,tt1431045,tt0458525  Deadpool 2      2018.0
# 4  tt1502712,tt3315342,tt1877832,tt3659388  Deadpool 2      2018.0
#
#    runtime_minutes                   genres  id release_date  \
# 0            119.0  Action,Adventure,Comedy  15   2018-05-18
# 1            119.0  Action,Adventure,Comedy  15   2018-05-18
# 2            119.0  Action,Adventure,Comedy  15   2018-05-18
# 3            119.0  Action,Adventure,Comedy  15   2018-05-18
# 4            119.0  Action,Adventure,Comedy  15   2018-05-18
#
#    production_budget  domestic_gross  worldwide_gross  international_gross  \
# 0          110000000       324591735        786680557            462088822
# 1          110000000       324591735        786680557            462088822
# 2          110000000       324591735        786680557            462088822
# 3          110000000       324591735        786680557            462088822
# 4          110000000       324591735        786680557            462088822
#
#       profit
# 0  676680557
# 1  676680557
# 2  676680557
# 3  676680557
# 4  676680557

# %%
#cleaned the data set by dropping NaN values from the dataset- there was a very small percentage of NaN values in the data set, so the removal of them did not skew the data
tnfinal = tnfinal.dropna()
tnfinal
# Out:
#          tconst  ordering     nconst         category            primary_name  \
# 0     tt5463162       2.0  nm0000982            actor             Josh Brolin
# 1     tt5463162       6.0  nm1014201           writer             Rhett Reese
# 2     tt5463162       7.0  nm1116660           writer            Paul Wernick
# 3     tt5463162       1.0  nm0005351            actor           Ryan Reynolds
# 4     tt5463162      10.0  nm1334526         producer           Simon Kinberg
# 5     tt5463162       3.0  nm1072555          actress         Morena Baccarin
# 6     tt5463162       5.0  nm0500610         director            David Leitch
# 7     tt5463162       4.0  nm5421877            actor         Julian Dennison
# 8     tt5463162       8.0  nm0509580           writer             Rob Liefeld
# 9     tt5463162       9.0  nm1436760           writer          Fabian Nicieza
# 10    tt1454468       2.0  nm0000123            actor          George Clooney
# 11    tt1454468       1.0  nm0000113          actress          Sandra Bullock
# 12    tt1454468       3.0  nm0000438            actor               Ed Harris
# 13    tt1454468       9.0  nm0523881  cinematographer        Emmanuel Lubezki
# 14    tt1454468       8.0  nm1888527         composer            Steven Price
# 15    tt1454468       5.0  nm0190859         director          Alfonso Cuarón
# 16    tt1454468      10.0  nm0002747           editor             Mark Sanger
# 17    tt1454468       4.0  nm1241511            actor        Orto Ignatiussen
# 18    tt1454468       6.0  nm0190861           writer            Jonás Cuarón
# 19    tt1454468       7.0  nm0382268         producer            David Heyman
# 20    tt2379713       4.0  nm0000146            actor           Ralph Fiennes
# 21    tt2379713       3.0  nm2244205          actress             Léa Seydoux
# 22    tt2379713       9.0  nm0125336           writer         Jez Butterworth
# 23    tt2379713       2.0  nm0910607            actor         Christoph Waltz
# 24    tt2379713       6.0  nm0517589           writer              John Logan
# 25    tt2379713       1.0  nm0185819            actor            Daniel Craig
# 26    tt2379713       7.0  nm0701031           writer             Neal Purvis
# 27    tt2379713       8.0  nm0905498           writer             Robert Wade
# 28    tt2379713       5.0  nm0005222         director              Sam Mendes
# 29    tt2379713      10.0  nm0001220           writer             Ian Fleming
# ...         ...       ...        ...              ...                     ...
# 989   tt3606756       8.0  nm0315974         composer       Michael Giacchino
# 990   tt3606756       2.0  nm0000456          actress            Holly Hunter
# 991   tt3606756       5.0  nm0083348         director               Brad Bird
# 992   tt3606756      10.0  nm1733986  cinematographer              Erik Smitt
# 993   tt3606756       1.0  nm0005266            actor         Craig T. Nelson
# 994   tt3606756       3.0  nm1102970          actress            Sarah Vowell
# 995   tt3606756       4.0  nm9133740            actor             Huck Milner
# 996   tt3606756       6.0  nm0342430         producer  Nicole Paradis Grindle
# 997   tt3606756       7.0  nm0907869         producer             John Walker
# 998   tt3606756       9.0  nm1743277  cinematographer       Mahyar Abousaeedi
# 999   tt1727824       9.0  nm0454752         producer             Graham King
# 1000  tt1727824       7.0  nm0604948           writer            Peter Morgan
# 1001  tt1727824       5.0  nm0001741         director            Bryan Singer
# 1002  tt1727824      10.0  nm0653211         composer             John Ottman
# 1003  tt1727824       1.0  nm1785339            actor              Rami Malek
# 1004  tt1727824       2.0  nm2377903          actress            Lucy Boynton
# 1005  tt1727824       3.0  nm3152605            actor              Gwilym Lee
# 1006  tt1727824       4.0  nm5228887            actor               Ben Hardy
# 1007  tt1727824       6.0  nm0565026           writer        Anthony McCarten
# 1008  tt1727824       8.0  nm0063473         producer               Jim Beach
# 1009  tt1386697       9.0  nm1888527         composer            Steven Price
# 1010  tt1386697       7.0  nm0746273         producer           Charles Roven
# 1011  tt1386697       1.0  nm0000226            actor              Will Smith
# 1012  tt1386697       4.0  nm0205626          actress             Viola Davis
# 1013  tt1386697       5.0  nm0043742         director              David Ayer
# 1014  tt1386697       3.0  nm3053338          actress           Margot Robbie
# 1015  tt1386697       2.0  nm0001467            actor              Jared Leto
# 1016  tt1386697       8.0  nm0837112         producer          Richard Suckle
# 1017  tt1386697      10.0  nm1664042  cinematographer          Roman Vasyanov
# 1018  tt1386697       6.0  nm1694619           writer          John Ostrander
#
#                              known_for_titles              movie  start_year  \
# 0     tt4154756,tt1175491,tt0477348,tt1791528         Deadpool 2      2018.0
# 1     tt5442430,tt1156398,tt1583421,tt1431045         Deadpool 2      2018.0
# 2     tt1431045,tt5442430,tt1156398,tt1583421         Deadpool 2      2018.0
# 19            110000000       274092705        693698673            419605968
# 20            300000000       200074175        879620923            679546748
# 21            300000000       200074175        879620923            679546748
# 22            300000000       200074175        879620923            679546748
# 23            300000000       200074175        879620923            679546748
# 24            300000000       200074175        879620923            679546748
# 25            300000000       200074175        879620923            679546748
# 26            300000000       200074175        879620923            679546748
# 27            300000000       200074175        879620923            679546748
# 28            300000000       200074175        879620923            679546748
# 29            300000000       200074175        879620923            679546748
# ...                 ...             ...              ...                  ...
# 989           200000000       608581744       1242520711            633938967
# 990           200000000       608581744       1242520711            633938967
# 991           200000000       608581744       1242520711            633938967
# 992           200000000       608581744       1242520711            633938967
# 993           200000000       608581744       1242520711            633938967
# 994           200000000       608581744       1242520711            633938967
# 995           200000000       608581744       1242520711            633938967
# 996           200000000       608581744       1242520711            633938967
# 997           200000000       608581744       1242520711            633938967
# 998           200000000       608581744       1242520711            633938967
# 999            55000000       216303339        894985342            678682003
# 1000           55000000       216303339        894985342            678682003
# 1001           55000000       216303339        894985342            678682003
# 1002           55000000       216303339        894985342            678682003
# 1003           55000000       216303339        894985342            678682003
# 1004           55000000       216303339        894985342            678682003
# 1005           55000000       216303339        894985342            678682003
# 1006           55000000       216303339        894985342            678682003
# 1007           55000000       216303339        894985342            678682003
# 1008           55000000       216303339        894985342            678682003
# 1009          175000000       325100054        746059887            420959833
# 1010          175000000       325100054        746059887            420959833
# 1011          175000000       325100054        746059887            420959833
# 1012          175000000       325100054        746059887            420959833
# 1013          175000000       325100054        746059887            420959833
# 1014          175000000       325100054        746059887            420959833
# 1015          175000000       325100054        746059887            420959833
# 1016          175000000       325100054        746059887            420959833
# 1017          175000000       325100054        746059887            420959833
# 1018          175000000       325100054        746059887            420959833
#
#           profit
# 0      676680557
# 1      676680557
# 2      676680557
# 3      676680557
# 4      676680557
# 5      676680557
# 6      676680557
# 7      676680557
# 8      676680557
# 9      676680557
# 10     583698673
# 11     583698673
# 12     583698673
# 13     583698673
# 14     583698673
# 15     583698673
# 16     583698673
# 17     583698673
# 18     583698673
# 19     583698673
# 20     579620923
# 21     579620923
# 22     579620923
# 23     579620923
# 24     579620923
# 25     579620923
# 26     579620923
# 27     579620923
# 28     579620923
# 29     579620923
# ...          ...
# 989   1042520711
# 990   1042520711
# 991   1042520711
# 992   1042520711
# 993   1042520711
# 994   1042520711
# 995   1042520711
# 996   1042520711
# 997   1042520711
# 998   1042520711
# 999    839985342
# 1000   839985342
# 1001   839985342
# 1002   839985342
# 1003   839985342
# 1004   839985342
# 1005   839985342
# 1006   839985342
# 1007   839985342
# 1008   839985342
# 1009   571059887
# 1010   571059887
# 1011   571059887
# 1012   571059887
# 1013   571059887
# 1014   571059887
# 1015   571059887
# 1016   571059887
# 1017   571059887
# 1018   571059887
#
# [998 rows x 17 columns]

# %%
#roles of cast
tncategory = tnfinal.groupby('category').size()
tncategory
# Out:
# category
# actor                  273
# actress                123
# cinematographer         15
# composer                44
# director               127
# editor                  12
# producer               108
# production_designer      3
# self                     5
# writer                 288
# dtype: int64

# %%
#created dataset of names of cast
tnnames = tnfinal.groupby(['primary_name', 'category']).size()

#sorted the names in descending order based on how many times each name appears in the data set
tnnamessorted = tnnames.sort_values(ascending=False)
tnnamessorted
# Out:
# primary_name             category
# Stan Lee                 writer             10
# Jack Kirby               writer              7
# Robert Downey Jr.        actor               6
# Dwayne Johnson           actor               5
# Janet Healy              producer            5
# Chris Evans              actor               5
# Christopher Markus       writer              4
# Stephen McFeely          writer              4
# Vin Diesel               actor               4
# Cinco Paul               writer              4
# Ian McKellen             actor               4
# Jon Kilik                producer            4
# Nina Jacobson            producer            4
# Johnny Depp              actor               4
# Suzanne Collins          writer              4
# Liam Hemsworth           actor               4
# Kevin Feige              producer            4
# Jennifer Lawrence        actress             4
# Ken Daurio               writer              4
# Scarlett Johansson       actress             4
# Josh Hutcherson          actor               4
# Chris Hemsworth          actor               4
# J.R.R. Tolkien           writer              3
# Ted Elliott              writer              3
# Anthony Russo            director            3
# Gary Scott Thompson      writer              3
# Guillermo del Toro       writer              3
# Bradley Cooper           actor               3
# Carolynne Cunningham     producer            3
# Cate Blanchett           actress             3
#                                             ..
# Lauren Chapman           producer            1
# Lan Wei                  actress             1
# Lake Bell                actress             1
# Ladj Ly                  self                1
# Kyle Lawrence            director            1
# Kyle Gallner             actor               1
# Kristen Stewart          actress             1
# Kristen Bell             actress             1
# Kristen Anderson-Lopez   composer            1
# Lewis Black              actor               1
# Lewis Carroll            writer              1
# Lindsey Collins          producer            1
# Mackenley Benoit         self                1
# Margot Robbie            actress             1
# Marcos Cano              actor               1
# Marc Hyman               writer              1
# Man of Action            writer              1
# Mahyar Abousaeedi        cinematographer     1
# Madison Vollmer          actress             1
# Mackenzie Foy            actress             1
# Lynda Obst               producer            1
# Lori Forte               writer              1
# Lupita Nyong'o           actress             1
# Luke Evans               actor               1
# Ludwig Göransson         composer            1
# Lucy Rodriguez Sandoval  actress             1
# Lucy Davis               actress             1
# Lucy Boynton             actress             1
# Louis C.K.               actor               1
# Aarif Rahman             actor               1
# Length: 751, dtype: int64

# %%
#created data set that uses names (without corresponding categories) for visualization purposes
tnnames2 = tnfinal.groupby('primary_name').size()
print(tnnames2.value_counts())
tnnamessorted2 = tnnames2.sort_values(ascending=False)
tnnamessorted2
# Out:
# 1     586
# 2      97
# 3      36
# 4      18
# 5       3
# 10      1
# 7       1
# 6       1
# dtype: int64
# primary_name
# Stan Lee                   10
# Jack Kirby                  7
# Robert Downey Jr.           6
# Dwayne Johnson              5
# Chris Evans                 5
# Janet Healy                 5
# Simon Kinberg               4
# Scarlett Johansson          4
# Liam Hemsworth              4
# Stephen McFeely             4
# Chris Hemsworth             4
# Christopher Markus          4
# Pierre Coffin               4
# Cinco Paul                  4
# Nina Jacobson               4
# Suzanne Collins             4
# Vin Diesel                  4
# Jennifer Lawrence           4
# Josh Hutcherson             4
# Ian McKellen                4
# Jon Kilik                   4
# Ken Daurio                  4
# Johnny Depp                 4
# Kevin Feige                 4
# Bradley Cooper              3
# James Newton Howard         3
# Carolynne Cunningham        3
# Cate Blanchett              3
# Joe Simon                   3
# J.R.R. Tolkien              3
#                            ..
# Lake Bell                   1
# Ladj Ly                     1
# Kyle Lawrence               1
# Kyle Gallner                1
# Kristen Stewart             1
# Kristen Bell                1
# Kristen Anderson-Lopez      1
# Kori Rae                    1
# Kodi Smit-McPhee            1
# Leonardo DiCaprio           1
# Lesley Manville             1
# Lewis Black                 1
# Lupita Nyong'o              1
# Marc Hyman                  1
# Man of Action               1
# Mahyar Abousaeedi           1
# Madison Vollmer             1
# Mackenzie Foy               1
# Mackenley Benoit            1
# Lynda Obst                  1
# Luke Evans                  1
# Lewis Carroll               1
# Ludwig Göransson            1
# Lucy Rodriguez Sandoval     1
# Lucy Davis                  1
# Lucy Boynton                1
# Louis C.K.                  1
# Lori Forte                  1
# Lindsey Collins             1
# Aarif Rahman                1
# Length: 743, dtype: int64

# %%
#split the genres to figure out how many individual appearances each genre makes in the data set
tngenres = tnfinal.genres.str.split(",",expand=True)

print(tngenres.groupby(0).size())
print(tngenres.groupby(1).size())
tngenres.groupby(2).size()
# Out:
# 0
# Action         500
# Adventure      290
# Animation       29
# Biography       20
# Comedy          30
# Crime           10
# Documentary     12
# Drama           30
# Family          24
# Fantasy         17
# Horror          19
# Sci-Fi           7
# Thriller        10
# dtype: int64
# 1
# Adventure      430
# Animation      170
# Biography       10
# Comedy          20
# Crime           30
# Documentary     10
# Drama          104
# Family          40
# Fantasy         56
# Musical          7
# Mystery         10
# Romance         20
# Sci-Fi          20
# Thriller        20
# dtype: int64
# 2
# Animation     40
# Comedy       230
# Drama         20
# Family        50
# Fantasy      140
# History       10
# Music         10
# Musical       16
# Romance       10
# Sci-Fi       240
# Sport         14
# Thriller      80
# dtype: int64

# %%
#created dictionary of genres in tn dataset to show frequency of how many times these genres appeared
tngenresdict = {'Action': 500, 'Adventure': 290 + 430, 'Animation': 29 + 170 + 40, 'Biography': 17 + 10, 'Comedy': 30 + 20 + 230, 'Crime': 10 + 30, 'Documentary': 11 + 7, 'Drama': 30 + 104 + 20, 'Family': 24 + 40 + 50, 'Fantasy': 17 + 40 + 140, 'History': 7, 'Horror': 19, 'Music': 10, 'Musical': 7 + 16, 'Mystery': 10, 'Romance': 20 + 10, 'Sci-Fi': 7 + 20 + 240, 'Sport': 14, 'Thriller': 10 + 20 + 80}
tngenresdict
# Out:
# {'Action': 500,
#  'Adventure': 720,
#  'Animation': 239,
#  'Biography': 27,
#  'Comedy': 280,
#  'Crime': 40,
#  'Documentary': 18,
#  'Drama': 154,
#  'Family': 114,
#  'Fantasy': 197,
#  'History': 7,
#  'Horror': 19,
#  'Music': 10,
#  'Musical': 23,
#  'Mystery': 10,
#  'Romance': 30,
#  'Sci-Fi': 267,
#  'Sport': 14,
#  'Thriller': 110}

# %%
plt.figure(figsize=(16,6))
sns.regplot(x = tn_2010_2018["production_budget"], y = tn_2010_2018["profit"], color = "blue")

# %%
plt.figure(figsize=(16,6))
ax = sns.scatterplot(x="production_budget", y="profit", edgecolor="blue", data=tn_2010_2018, s=5, lw=1 )

# %%
tnfinal.groupby('genres').count().sort_values(by='profit', ascending=False).plot(kind='bar', y='profit', figsize = (16,6))
